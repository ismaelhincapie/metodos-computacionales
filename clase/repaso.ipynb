# %%
list=[1,2,3,4,5]

n= len(list)

print("Length of list is: ",n)
# Out:
# Length of list is:  5

# %%
list.append(6)

print("Updated list: ",list)
# Out:
# Updated list:  [1, 2, 3, 4, 5, 6]

# %%
list[0:3] = [10,20,30]
print("Updated list: ",list)
# Out:
# Updated list:  [10, 20, 30, 4, 5, 6]
